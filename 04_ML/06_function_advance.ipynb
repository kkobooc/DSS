# %%
def test_args(a, *arg):
    print("첫 번째 인자" : a)
    for each in arg:
        print ("*arg 다른 인자", each)
# Out:
#   File "<ipython-input-18-c7c3b7caa794>", line 2
#     print("첫 번째 인자" : a)
#                     ^
# SyntaxError: invalid syntax

# %%
test_args("a", "b")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d75e749fe2aa> in <module>
# ----> 1 test_args("a", "b")
#
# NameError: name 'test_args' is not defined

# %%
def test_kwargs(**kwargs):
    print(kwargs)

# %%
test_kwargs(A='aa', B='bb')
# Out:
# {'A': 'aa', 'B': 'bb'}

# %%
def test_kwargs(**kwargs):
    if kwargs is not None:
        for key, value in kwargs.items():
            print(key, " : ", value)

# %%
test_kwargs(A='aa', B='bb')
# Out:
# A  :  aa
# B  :  bb

# %%
def test_kwargs(**kwargs):
    A = kwargs.get("A", 1)
    print(A)
    
test_kwargs()
# Out:
# 1

# %%
test_kwargs(A=10)
# Out:
# 10

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def plotSinWave(amp, freq, endTime, sampleTime, bias):
    """
    plot sine wave
    y = a sin(s pi f t) + b
    """
    time = np.arange(0, endTime, sampleTime)
    result = amp * np.sin(2*np.pi*freq*time) + bias
    
    plt.figure(figsize=(12,6))
    plt.plot(time, result); plt.grid(True)
    plt.xlabel("time"); plt.ylabel("sin")
    plt.title(str(amp) + "sin(2*pi*"+str(freq)+"*t )+"+str(bias))
    plt.show()
    
plotSinWave(2, 1, 10, 0.01, 0)

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 512 kB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /Users/jaecheolchoi/opt/anaconda3/envs/dss/lib/python3.7/site-packages (from selenium) (1.25.11)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
